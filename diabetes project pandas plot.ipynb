# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # pandas functions

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# 1.to display prticular top rows data  
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# 2.to give information
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
# 3.to driscribe data
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# 4.to show shape of data
df.shape
# Out:
# (768, 9)

# %%
# 5.to show size of data
df.size
# Out:
# 6912

# %%
# 6.to find length
len(df)
# Out:
# 768

# %%
#7.to find datatypes
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# 8.to dislay bottom rows
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#9.to display perticular columns acc to datatypes
df.select_dtypes(include='int64')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  Age  Outcome
# 0              6      148             72             35        0   50        1
# 1              1       85             66             29        0   31        0
# 2              8      183             64              0        0   32        1
# 3              1       89             66             23       94   21        0
# 4              0      137             40             35      168   33        1
# ..           ...      ...            ...            ...      ...  ...      ...
# 763           10      101             76             48      180   63        0
# 764            2      122             70             27        0   27        0
# 765            5      121             72             23      112   30        0
# 766            1      126             60              0        0   47        1
# 767            1       93             70             31        0   23        0
#
# [768 rows x 7 columns]

# %%
#10.random data show
df.sample(20)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 93             4      134             72              0        0  23.8
# 95             6      144             72             27      228  33.9
# 386            5      116             74             29        0  32.3
# 7             10      115              0              0        0  35.3
# 68             1       95             66             13       38  19.6
# 592            3      132             80              0        0  34.4
# 75             1        0             48             20        0  24.7
# 646            1      167             74             17      144  23.4
# 315            2      112             68             22       94  34.1
# 81             2       74              0              0        0   0.0
# 153            1      153             82             42      485  40.6
# 428            0      135             94             46      145  40.6
# ...

# %%
# 11.show how many memory used
df.memory_usage()
# Out:
# Index                        128
# Pregnancies                 6144
# Glucose                     6144
# BloodPressure               6144
# SkinThickness               6144
# Insulin                     6144
# BMI                         6144
# DiabetesPedigreeFunction    6144
# Age                         6144
# Outcome                     6144
# dtype: int64

# %%
# 12.to columns name
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#13.to get perticular columns
df.get(['Glucose','Insulin'])
# Out:
#      Glucose  Insulin
# 0        148        0
# 1         85        0
# 2        183        0
# 3         89       94
# 4        137      168
# ..       ...      ...
# 763      101      180
# 764      122        0
# 765      121      112
# 766      126        0
# 767       93        0
#
# [768 rows x 2 columns]

# %%
# 14.to get perticular row
df.asof([3,5,6])
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 5          5.0    116.0           74.0            0.0      0.0  25.6
# 6          3.0     78.0           50.0           32.0     88.0  31.0
#
#    DiabetesPedigreeFunction   Age  Outcome
# 3                     0.167  21.0      0.0
# 5                     0.201  30.0      0.0
# 6                     0.248  26.0      1.0

# %%
# 15 to find perticular position 
df.at[3,'BMI']
# Out:
# 28.1

# %%
#16 Subset the dataframe rows or columns according to the specified index labels
df.filter(items=['BloodPressure', 'Age'])
# Out:
#      BloodPressure  Age
# 0               72   50
# 1               66   31
# 2               64   32
# 3               66   21
# 4               40   33
# ..             ...  ...
# 763             76   63
# 764             70   27
# 765             72   30
# 766             60   47
# 767             70   23
#
# [768 rows x 2 columns]

# %%
# 17 using loc index or column names display data
dt=df.loc[0:99,['Pregnancies','Age','Insulin','BMI']]
dt
# Out:
#     Pregnancies  Age  Insulin   BMI
# 0             6   50        0  33.6
# 1             1   31        0  26.6
# 2             8   32        0  23.3
# 3             1   21       94  28.1
# 4             0   33      168  43.1
# ..          ...  ...      ...   ...
# 95            6   40      228  33.9
# 96            2   24        0  31.6
# 97            1   22       76  20.4
# 98            6   23       64  28.7
# 99            1   31      220  49.7
#
# [100 rows x 4 columns]

# %%
#18. using iloc indexes to display peticular data
dd=df.iloc[10:50,4:]
dd
# Out:
#     Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 10        0  37.6                     0.191   30        0
# 11        0  38.0                     0.537   34        1
# 12        0  27.1                     1.441   57        0
# 13      846  30.1                     0.398   59        1
# 14      175  25.8                     0.587   51        1
# 15        0  30.0                     0.484   32        1
# 16      230  45.8                     0.551   31        1
# 17        0  29.6                     0.254   31        1
# 18       83  43.3                     0.183   33        0
# 19       96  34.6                     0.529   32        1
# 20      235  39.3                     0.704   27        0
# 21        0  35.4                     0.388   50        0
# 22        0  39.8                     0.451   41        1
# 23        0  29.0                     0.263   29        1
# 24      146  36.6                     0.254   51        1
# ...

# %%
#19. to check null value
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# 20. to fill null values
df.fillna(0)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#21.to count values
df.value_counts(['Pregnancies'])
# Out:
# Pregnancies
# 1              135
# 0              111
# 2              103
# 3               75
# 4               68
# 5               57
# 6               50
# 7               45
# 8               38
# 9               28
# 10              24
# 11              11
# 13              10
# 12               9
# 14               2
# 15               1
# 17               1
# dtype: int64

# %%
#22 delect non-missing values for an array-like object (return true & false)
pd.notna(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           True     True           True           True     True  True
# 1           True     True           True           True     True  True
# 2           True     True           True           True     True  True
# 3           True     True           True           True     True  True
# 4           True     True           True           True     True  True
# ..           ...      ...            ...            ...      ...   ...
# 763         True     True           True           True     True  True
# 764         True     True           True           True     True  True
# 765         True     True           True           True     True  True
# 766         True     True           True           True     True  True
# 767         True     True           True           True     True  True
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                        True  True     True
# ...

# %%
#23 to replace values
df['Pregnancies'].replace(6,'diff')  # to make permanant change use (inplace=true)
# Out:
# 0      diff
# 1         1
# 2         8
# 3         1
# 4         0
#        ...
# 763      10
# 764       2
# 765       5
# 766       1
# 767       1
# Name: Pregnancies, Length: 768, dtype: object

# %%
#24. to rename column name
df.rename(columns={'BloodPressure':"BP"})
# Out:
#      Pregnancies  Glucose  BP  SkinThickness  Insulin   BMI  \
# 0              6      148  72             35        0  33.6
# 1              1       85  66             29        0  26.6
# 2              8      183  64              0        0  23.3
# 3              1       89  66             23       94  28.1
# 4              0      137  40             35      168  43.1
# ..           ...      ...  ..            ...      ...   ...
# 763           10      101  76             48      180  32.9
# 764            2      122  70             27        0  36.8
# 765            5      121  72             23      112  26.2
# 766            1      126  60              0        0  30.1
# 767            1       93  70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# ...

# %%
# 25. creating new columns using existing columns
dt['Avg_IB']=(dt['Insulin']+dt['BMI'])/2

# %%
dt
# Out:
#     Pregnancies  Age  Insulin   BMI  Avg_IB
# 0             6   50        0  33.6   16.80
# 1             1   31        0  26.6   13.30
# 2             8   32        0  23.3   11.65
# 3             1   21       94  28.1   61.05
# 4             0   33      168  43.1  105.55
# ..          ...  ...      ...   ...     ...
# 95            6   40      228  33.9  130.95
# 96            2   24        0  31.6   15.80
# 97            1   22       76  20.4   48.20
# 98            6   23       64  28.7   46.35
# 99            1   31      220  49.7  134.85
#
# [100 rows x 5 columns]

# %%
# 26. add neww column using function
def ad(x):
    if (x>=25):
        return("man")
    else:
        return("boy")
dt['cata']=dt['Age'].apply(ad)

# %%
dt
# Out:
#     Pregnancies  Age  Insulin   BMI  Avg_IB cata
# 0             6   50        0  33.6   16.80  man
# 1             1   31        0  26.6   13.30  man
# 2             8   32        0  23.3   11.65  man
# 3             1   21       94  28.1   61.05  boy
# 4             0   33      168  43.1  105.55  man
# ..          ...  ...      ...   ...     ...  ...
# 95            6   40      228  33.9  130.95  man
# 96            2   24        0  31.6   15.80  boy
# 97            1   22       76  20.4   48.20  boy
# 98            6   23       64  28.7   46.35  boy
# 99            1   31      220  49.7  134.85  man
#
# [100 rows x 6 columns]

# %%
#27. insert new columns
col1=np.random.randint(1,len(dt))  # we can use arange also
dt.insert(0,'NO',col1)

# %%
dt
# Out:
#     NO  Pregnancies  Age  Insulin   BMI  Avg_IB cata
# 0   63            6   50        0  33.6   16.80  man
# 1   63            1   31        0  26.6   13.30  man
# 2   63            8   32        0  23.3   11.65  man
# 3   63            1   21       94  28.1   61.05  boy
# 4   63            0   33      168  43.1  105.55  man
# ..  ..          ...  ...      ...   ...     ...  ...
# 95  63            6   40      228  33.9  130.95  man
# 96  63            2   24        0  31.6   15.80  boy
# 97  63            1   22       76  20.4   48.20  boy
# 98  63            6   23       64  28.7   46.35  boy
# 99  63            1   31      220  49.7  134.85  man
#
# [100 rows x 7 columns]

# %%
#28. # Compute the pairwise covariance among the series of a DataFrame. The returned data frame is the covariance matrix of the columns of the DataFrame.
df.cov()
# Out:
#                           Pregnancies      Glucose  BloodPressure  \
# Pregnancies                 11.354056    13.947131       9.214538
# Glucose                     13.947131  1022.248314      94.430956
# BloodPressure                9.214538    94.430956     374.647271
# SkinThickness               -4.390041    29.239183      64.029396
# Insulin                    -28.555231  1220.935799     198.378412
# BMI                          0.469774    55.726987      43.004695
# DiabetesPedigreeFunction    -0.037426     1.454875       0.264638
# Age                         21.570620    99.082805      54.523453
# Outcome                      0.356618     7.115079       0.600697
#
#                           SkinThickness       Insulin         BMI  \
# Pregnancies                   -4.390041    -28.555231    0.469774
# Glucose                       29.239183   1220.935799   55.726987
# BloodPressure                 64.029396    198.378412   43.004695
# ...

# %%
#29. remove perticular data
dt.drop('NO',axis=1)  #to remove row use axis=0
# Out:
#     Pregnancies  Age  Insulin   BMI  Avg_IB cata
# 0             6   50        0  33.6   16.80  man
# 1             1   31        0  26.6   13.30  man
# 2             8   32        0  23.3   11.65  man
# 3             1   21       94  28.1   61.05  boy
# 4             0   33      168  43.1  105.55  man
# ..          ...  ...      ...   ...     ...  ...
# 95            6   40      228  33.9  130.95  man
# 96            2   24        0  31.6   15.80  boy
# 97            1   22       76  20.4   48.20  boy
# 98            6   23       64  28.7   46.35  boy
# 99            1   31      220  49.7  134.85  man
#
# [100 rows x 6 columns]

# %%
# pop
dt.pop('cata')  #remove column permanant
# Out:
# 0     man
# 1     man
# 2     man
# 3     boy
# 4     man
#      ...
# 95    man
# 96    boy
# 97    boy
# 98    boy
# 99    man
# Name: cata, Length: 100, dtype: object

# %%
#30. Trim values at input threshold
df.clip(-4, 6)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0              6        6              6              6        0  6.0
# 1              1        6              6              6        0  6.0
# 2              6        6              6              0        0  6.0
# 3              1        6              6              6        6  6.0
# 4              0        6              6              6        6  6.0
# ..           ...      ...            ...            ...      ...  ...
# 763            6        6              6              6        6  6.0
# 764            2        6              6              6        0  6.0
# 765            5        6              6              6        6  6.0
# 766            1        6              6              0        0  6.0
# 767            1        6              6              6        0  6.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627    6        1
# ...

# %%
#31. to check data is avalable or not
dt.isin([2]).sum()
# Out:
# NO              0
# Pregnancies    13
# Age             0
# Insulin         0
# BMI             0
# Avg_IB          0
# dtype: int64

# %%
# 32. to find maximum value
df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
#33. to find minimum value
df['Age'].min()
# Out:
# 21

# %%
#34.Compare DataFrames for equality elementwise
df.eq(6)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0           True    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
#35. find largest number
df.nlargest(5,'Age')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# 453                     0.832   72        0
# 666                     0.235   70        1
# 123                     0.186   69        0
# 684                     0.640   69        0

# %%
df.nsmallest(3,'BMI')
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 9             8      125             96              0        0  0.0
# 49            7      105              0              0        0  0.0
# 60            2       84              0              0        0  0.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 9                      0.232   54        1
# 49                     0.305   24        0
# 60                     0.304   21        0

# %%
#36. to sorting values 
df.sort_values(by="BloodPressure")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 347            3      116              0              0        0  23.5
# 494            3       80              0              0        0   0.0
# 222            7      119              0              0        0  25.2
# 81             2       74              0              0        0   0.0
# 78             0      131              0              0        0  43.2
# ..           ...      ...            ...            ...      ...   ...
# 549            4      189            110             31        0  28.5
# 43             9      171            110             24      240  45.4
# 177            0      129            110             46      130  67.1
# 691           13      158            114              0        0  42.3
# 106            1       96            122              0        0  22.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 347                     0.187   23        0
# ...

# %%
# 37. masking
a=df[df['Pregnancies']==0]
a
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      137             40             35      168  43.1
# 16             0      118             84             47      230  45.8
# 45             0      180             66             39        0  42.0
# 57             0      100             88             60      110  46.8
# 58             0      146             82              0        0  40.5
# ..           ...      ...            ...            ...      ...   ...
# 713            0      134             58             20      291  26.4
# 727            0      141             84             26        0  32.4
# 736            0      126             86             27      120  27.4
# 753            0      181             88             44      510  43.3
# 757            0      123             72              0        0  36.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# ...

# %%
# 38. to show unique vaalue of columns
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
df['SkinThickness'].unique()
# Out:
# array([35, 29,  0, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31,
#        37, 42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40,
#        51, 56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
# 39. to cut data values
pd.cut(df['SkinThickness'],4)
# Out:
# 0        (24.75, 49.5]
# 1        (24.75, 49.5]
# 2      (-0.099, 24.75]
# 3      (-0.099, 24.75]
# 4        (24.75, 49.5]
#             ...
# 763      (24.75, 49.5]
# 764      (24.75, 49.5]
# 765    (-0.099, 24.75]
# 766    (-0.099, 24.75]
# 767      (24.75, 49.5]
# Name: SkinThickness, Length: 768, dtype: category
# Categories (4, interval[float64, right]): [(-0.099, 24.75] < (24.75, 49.5] < (49.5, 74.25] < (74.25, 99.0]]

# %%
pd.cut(df['SkinThickness'],4)
# Out:
# 0        (24.75, 49.5]
# 1        (24.75, 49.5]
# 2      (-0.099, 24.75]
# 3      (-0.099, 24.75]
# 4        (24.75, 49.5]
#             ...
# 763      (24.75, 49.5]
# 764      (24.75, 49.5]
# 765    (-0.099, 24.75]
# 766    (-0.099, 24.75]
# 767      (24.75, 49.5]
# Name: SkinThickness, Length: 768, dtype: category
# Categories (4, interval[float64, right]): [(-0.099, 24.75] < (24.75, 49.5] < (49.5, 74.25] < (74.25, 99.0]]

# %%
# 40 to find duplicates values
df['SkinThickness'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 763     True
# 764     True
# 765     True
# 766     True
# 767     True
# Name: SkinThickness, Length: 768, dtype: bool

# %%
df['SkinThickness'].drop_duplicates()
# Out:
# 0      35
# 1      29
# 2       0
# 3      23
# 6      32
# 8      45
# 14     19
# 16     47
# 18     38
# 19     30
# 20     41
# 24     33
# 25     26
# 27     15
# 31     36
# 32     11
# 34     31
# 37     37
# 38     42
# 40     25
# 42     18
# 43     24
# 45     39
# 47     27
# 52     21
# 53     34
# 55     10
# 57     60
# 68     13
# 70     20
# 79     22
# 83     28
# 86     54
# 92     40
# 99     51
# 120    56
# 130    14
# 149    17
# 150    50
# 155    44
# 169    12
# 177    46
# 200    16
# 254     7
# 275    52
# 289    43
# 370    48
# 382     8
# 409    49
# 445    63
# 579    99
# Name: SkinThickness, dtype: int64

# %%
#41.groupby data
df.groupby('SkinThickness').count()
# Out:
#                Pregnancies  Glucose  BloodPressure  Insulin  BMI  \
# SkinThickness
# 0                      227      227            227      227  227
# 7                        2        2              2        2    2
# 8                        2        2              2        2    2
# 10                       5        5              5        5    5
# 11                       6        6              6        6    6
# 12                       7        7              7        7    7
# 13                      11       11             11       11   11
# 14                       6        6              6        6    6
# 15                      14       14             14       14   14
# 16                       6        6              6        6    6
# 17                      14       14             14       14   14
# 18                      20       20             20       20   20
# 19                      18       18             18       18   18
# ...

# %%
# 42. concat 2 dataframess
b1=df.loc[0:10,['BloodPressure','BMI']]
b2=df.loc[0:10,['Age','Outcome']]

# %%
b3=b1+b2

# %%
b4=pd.concat([b1,b2])
b4
# Out:
#     BloodPressure   BMI   Age  Outcome
# 0            72.0  33.6   NaN      NaN
# 1            66.0  26.6   NaN      NaN
# 2            64.0  23.3   NaN      NaN
# 3            66.0  28.1   NaN      NaN
# 4            40.0  43.1   NaN      NaN
# 5            74.0  25.6   NaN      NaN
# 6            50.0  31.0   NaN      NaN
# 7             0.0  35.3   NaN      NaN
# 8            70.0  30.5   NaN      NaN
# 9            96.0   0.0   NaN      NaN
# 10           92.0  37.6   NaN      NaN
# 0             NaN   NaN  50.0      1.0
# 1             NaN   NaN  31.0      0.0
# 2             NaN   NaN  32.0      1.0
# 3             NaN   NaN  21.0      0.0
# 4             NaN   NaN  33.0      1.0
# 5             NaN   NaN  30.0      0.0
# 6             NaN   NaN  26.0      1.0
# 7             NaN   NaN  29.0      0.0
# 8             NaN   NaN  53.0      1.0
# 9             NaN   NaN  54.0      1.0
# 10            NaN   NaN  30.0      0.0

# %%
#43 join 2 dataframe
b2.join(b1,lsuffix='Outcome')
# Out:
#     Age  Outcome  BloodPressure   BMI
# 0    50        1             72  33.6
# 1    31        0             66  26.6
# 2    32        1             64  23.3
# 3    21        0             66  28.1
# 4    33        1             40  43.1
# 5    30        0             74  25.6
# 6    26        1             50  31.0
# 7    29        0              0  35.3
# 8    53        1             70  30.5
# 9    54        1             96   0.0
# 10   30        0             92  37.6

# %%
#44. to copy data
t=df.copy()
t
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#45. use rank to display rank column
t['ranks']=t['Pregnancies'].rank()

# %%
t
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  ranks
# 0                       0.627   50        1  574.5
# ...

# %%
#46 pandas.DataFrame.aggregate
df.agg(['sum','min','max'])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin      BMI  \
# sum         2953    92847          53073          15772    61286  24570.3
# min            0        0              0              0        0      0.0
# max           17      199            122             99      846     67.1
#
#      DiabetesPedigreeFunction    Age  Outcome
# sum                   362.401  25529      268
# min                     0.078     21        0
# max                     2.420     81        1

# %%
#47 Truncate a Series or DataFrame before and after some index value.
df.truncate(before=2, after=44)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# ...

# %%
#48. Fill NaN values using an interpolation method. random value fill in nan
df.interpolate()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # plots

# %%
# boxplot
# data=['Outcome']
# plt.boxplot(data)
# plt.show()

# %%
#1. bar plot
df.plot(kind='bar',      #kind used to witch type of graph you want to display
        x='Pregnancies',
        y='Age',
        color='green')
 
# set the title
plt.title('BarPlot')
 
# show the plot
plt.show()

# %%
#2. scatter plot
df.plot(kind='scatter', x='Pregnancies', y='Age', color='red')
 
# set the title
plt.title('ScatterPlot')
 
# show the plot
plt.show()

# %%
plt.scatter(df["Pregnancies"], df["Age"])

plt.show()

# %%
#3. pie plot
plt.pie(df['Pregnancies'].value_counts(),autopct="%1.0f%%",startangle=90)

# set the title
plt.title("Distribution of Pregnancies Wise")

# show the plot
plt.show()

# %%
#4. histrogram plot
plt.hist(df["Age"])

# set the title
plt.title('Histrogram')

# show the plot
plt.show()

# %%
# Plotting Dataframe Histograms
df.hist(bins=50, figsize=(15,15))  #bins is equal to width
plt.show()

# %%
# 5 area plot
df.plot(kind='area', figsize=(9,6))         
plt.title('Area plot')
plt.show()

# %%
df.plot(kind='area', stacked=False, figsize=(9,6))
# Out:
# <AxesSubplot:>

# %%
#6.Hexbin Plot
df.plot(kind='hexbin', x='Age', y='BloodPressure', gridsize=10, figsize=(10,6))
plt.show()

# %%
# 7. Kernel Density Estimate plot
df.plot(kind='kde',bw_method=0.1)
plt.show()

# %%
# 8.line plot
df.plot( x='Pregnancies', y='Age', kind='line',figsize=(10,6))
plt.show()

# %%
#9. barh plot
df.plot( x='Pregnancies', y='Age', kind='barh',figsize=(10,6))
plt.show()

# %%
#10.density plot    same as kde
df.plot(y='Pregnancies',kind="density",figsize=(9,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # SNS plots

# %% [markdown]
# # Distribution Plots
# # 1.Pair Plot
# # 2.Joint Plot
# # 3.Dist-Plot
# # 4. Rug Plot

# %%
#1. pairplot
sns.pairplot(df)

# %%
# 2.Jointplot
sns.jointplot(df['Pregnancies'],df['Outcome'],kind='kde')

# %%
sns.jointplot(df['Pregnancies'],df['Age'])

# %%
# 3.distplot  it's display histro/line plot in one plot
sns.distplot(df['SkinThickness'])
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %%
#4. rugPlot
sns.rugplot(data=df)
plt.show()

# %% [markdown]
# # Categorical Plots
# # 5.* Bar Plot
# # 6. Count Plot
# # 7. Box Plot
# # 8. Violin Plot

# %%
#5 barplot with countplot
sns.barplot(x = 'Pregnancies', y ='Age',data=df)
sns.countplot(x = 'Pregnancies', data=df)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %%
#6.count plot
sns.countplot(x = 'Pregnancies', data=df)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %%
#7. boxplot
sns.boxplot(x='Age',y='BloodPressure',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='BloodPressure'>

# %%
#8. violinplot
sns.violinplot(x='BloodPressure',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Age'>

# %% [markdown]
# # Advanced Plots
# # 9. Strip Plot
# # 10. Swarm Plot

# %%
# 9. stripPlot
sns.stripplot(
    data=df, x="Glucose", y="BloodPressure",
    dodge=True, alpha=.25, zorder=1)
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='BloodPressure'>

# %%
#10. Swarmplot is very similar to the stripplot except the fact that the points are adjusted so that they do not overlap
sns.swarmplot(x='BloodPressure', y='Age', data=df)
plt.show()

# %% [markdown]
# # Matrix Plots
# # 11. Heat Map
# # 12. Cluster Map

# %%
#11. heatmap
sns.heatmap(df.corr(),cmap='tab20',annot=True,linewidth=2,linecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Grids
# # 13 facet grid
# # 14 regression plot

# %% [raw]
# # 13. Facet Grid
#
# sns.FacetGrid(df, col = 'Age', row = 'BloodPressure').map(sns.distplot, 'Glucose')

# %%
# Regression Plots
# 14.
sns.regplot(x='BMI',y='DiabetesPedigreeFunction',data=df)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='DiabetesPedigreeFunction'>

# %% [markdown]
# # 15 relational

# %%
#15. relational
plt.figure(figsize=(12,10))
sns.relplot(x = 'Age',y = 'BloodPressure',data = df,kind = 'line')

# %%
#16.* Lineplot  the responses for different events and regions
sns.lineplot(x="SkinThickness", y="Age",data=df,hue='Outcome')
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Age'>

# %%
#17. Factorplot
sns.factorplot(x='BloodPressure', y='Age', data=df)
plt.show()

# %%
# 18 cat plot
sns.catplot(data=df, x="BloodPressure", y="Age")
plt.show()

# %%
# 19. residuals
sns.residplot(x="Age", y="BloodPressure",data=df, lowess=True, color="g")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='BloodPressure'>

# %%
# Facetted ECDF plots
sns.set_theme(style="ticks")

colors = (250, 70, 50), (350, 70, 50)
cmap = sns.blend_palette(colors, input="husl", as_cmap=True)
sns.displot(
    df,
    x="BloodPressure", col="Age", hue="Pregnancies",
    kind="ecdf", aspect=.75, linewidth=2, palette=cmap,
)

# %%
# 20. multipleplots
x=df['Pregnancies']
y1=df['Glucose']
y2=df['BloodPressure']
plt.figure(figsize=(10,7))
plt.plot(x,y1,color="blue")
plt.plot(x,y2,color="red")
plt.legend(labels=['Pregnancies','GLu-BP'])
plt.show()

# %%
# 21 axvline to display the vertical line in min/max point of column 

Glucose_min=df["Glucose"].min()
Glucose_max=df["Glucose"].max()
plt.figure(figsize=(7,7))
df['Glucose'].hist(bins=10)
plt.title("Glucose-min distribution")
plt.axvline(Glucose_min,color="red")
plt.axvline(Glucose_max,color="yellow")
plt.show()

# %%
# axhline to display the horizontal lines in mean/median of column
Glucose_mean=df["Glucose"].mean()
Glucose_median=df["Glucose"].median()
plt.figure(figsize=(7,7))
df['Glucose'].hist(bins=10)
plt.title("Glucose-min distribution")
plt.axhline(Glucose_mean,color="red")
plt.axhline(Glucose_median,color="yellow")
plt.show()
